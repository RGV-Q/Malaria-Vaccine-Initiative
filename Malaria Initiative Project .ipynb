# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.chdir ('/users/grace/documents/datasets/')

# %%
pwd
# Out:
# '/Users/Grace/Documents/Datasets'

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://media.pri.org/s3fs-public/styles/story_main/public/story/images/18759_lores.jpg")
# Out:
# <img src="https://media.pri.org/s3fs-public/styles/story_main/public/story/images/18759_lores.jpg"/>

# %%
df= pd.read_csv('Malaria_report.csv')
df.head ()

#Let's take a brief look at our data.
#It looks messy. We need to clean it.
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  ...  \
# 0                   0.881686         0.517637  ...
# 1                   0.850035         0.583926  ...
# 2                   0.706766         0.618265  ...
# 3                   0.731109         0.611387  ...
# 4                   0.775620         0.710385  ...
#
#    GINI index (World Bank estimate)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    GINI index (World Bank estimate), average 2000-16  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    gini of household income reported in Gallup, by wp5-year  \
# 0                                                NaN
# 1                                           0.441906
# 2                                           0.327318
# 3                                           0.336764
# 4                                           0.344540
#
#    Most people can be trusted, Gallup  \
# 0                                 NaN
# 1                            0.286315
# 2                            0.275833
# 3                                 NaN
# 4                                 NaN
#
#    Most people can be trusted, WVS round 1981-1984  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1989-1993  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1994-1998  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1999-2004  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 2005-2009  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 2010-2014
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
# [5 rows x 26 columns]

# %%
print (df.shape)
print (df.dtypes)

#Let's first collect parameters.
# Out:
# (1704, 26)
# Country name                                                 object
# Year                                                          int64
# Life Ladder                                                 float64
# Log GDP per capita                                          float64
# Social support                                              float64
# Healthy life expectancy at birth                            float64
# Freedom to make life choices                                float64
# Generosity                                                  float64
# Perceptions of corruption                                   float64
# Positive affect                                             float64
# Negative affect                                             float64
# Confidence in national government                           float64
# Democratic Quality                                          float64
# Delivery Quality                                            float64
# Standard deviation of ladder by country-year                float64
# Standard deviation/Mean of ladder by country-year           float64
# GINI index (World Bank estimate)                            float64
# GINI index (World Bank estimate), average 2000-16           float64
# gini of household income reported in Gallup, by wp5-year    float64
# Most people can be trusted, Gallup                          float64
# Most people can be trusted, WVS round 1981-1984             float64
# Most people can be trusted, WVS round 1989-1993             float64
# Most people can be trusted, WVS round 1994-1998             float64
# Most people can be trusted, WVS round 1999-2004             float64
# Most people can be trusted, WVS round 2005-2009             float64
# Most people can be trusted, WVS round 2010-2014             float64
# dtype: object

# %%
df_numeric = df.select_dtypes (include=[np.number])
numeric_cols = df_numeric.columns.values
print(numeric_cols)

#Identifying numeric and non-numeric columns will be useful later when we are using values for our plots later on.
# Out:
# ['Year' 'Life Ladder' 'Log GDP per capita' 'Social support'
#  'Healthy life expectancy at birth' 'Freedom to make life choices'
#  'Generosity' 'Perceptions of corruption' 'Positive affect'
#  'Negative affect' 'Confidence in national government'
#  'Democratic Quality' 'Delivery Quality'
#  'Standard deviation of ladder by country-year'
#  'Standard deviation/Mean of ladder by country-year'
#  'GINI index (World Bank estimate)'
#  'GINI index (World Bank estimate), average 2000-16'
#  'gini of household income reported in Gallup, by wp5-year'
#  'Most people can be trusted, Gallup'
#  'Most people can be trusted, WVS round 1981-1984'
#  'Most people can be trusted, WVS round 1989-1993'
#  'Most people can be trusted, WVS round 1994-1998'
#  'Most people can be trusted, WVS round 1999-2004'
#  'Most people can be trusted, WVS round 2005-2009'
#  'Most people can be trusted, WVS round 2010-2014']

# %%
df_non_numeric=df.select_dtypes (exclude=[np.number])
non_numeric_cols = df_non_numeric.columns.values
print (non_numeric_cols)

#Identifying numeric and non-numeric columns will be useful later when we are using values for our plots later on.
# Out:
# ['Country name']

# %%
cols = df.columns [:20] 
colors = ['#000099', '#ffff00']
sns.heatmap (df[cols].isnull(), cmap=sns.color_palette(colors))

#Let's visualize missing data through a heatmap.

# %%
df= pd.read_csv('Malaria_report.csv')
df.head ()

#Now let's look at our dataset again, while comparing it to our heatmap above.
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  ...  \
# 0                   0.881686         0.517637  ...
# 1                   0.850035         0.583926  ...
# 2                   0.706766         0.618265  ...
# 3                   0.731109         0.611387  ...
# 4                   0.775620         0.710385  ...
#
#    GINI index (World Bank estimate)  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    GINI index (World Bank estimate), average 2000-16  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    gini of household income reported in Gallup, by wp5-year  \
# 0                                                NaN
# 1                                           0.441906
# 2                                           0.327318
# 3                                           0.336764
# 4                                           0.344540
#
#    Most people can be trusted, Gallup  \
# 0                                 NaN
# 1                            0.286315
# 2                            0.275833
# 3                                 NaN
# 4                                 NaN
#
#    Most people can be trusted, WVS round 1981-1984  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1989-1993  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1994-1998  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 1999-2004  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 2005-2009  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Most people can be trusted, WVS round 2010-2014
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
# [5 rows x 26 columns]

# %%
df= pd.read_csv('Malaria_report.csv')
df.head ()

to_drop = ['GINI index (World Bank estimate)', 'GINI index (World Bank estimate), average 2000-16', 'gini of household income reported in Gallup, by wp5-year','Most people can be trusted, Gallup','Most people can be trusted, WVS round 1981-1984','Most people can be trusted, WVS round 1989-1993','Most people can be trusted, WVS round 1994-1998','Most people can be trusted, WVS round 1994-1998','Most people can be trusted, WVS round 1999-2004','Most people can be trusted, WVS round 2005-2009','Most people can be trusted, WVS round 2010-2014']
df.drop (to_drop, inplace=True, axis=1)

#Now that we saw from our heatmap all our missing datapoints, 
#let's drop unneccesary data.

# %%
df.head ()

#Now let's look at our updated Dataset.
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# 0                   0.881686         0.517637         0.258195
# 1                   0.850035         0.583926         0.237092
# 2                   0.706766         0.618265         0.275324
# 3                   0.731109         0.611387         0.267175
# 4                   0.775620         0.710385         0.267919
#
#    Confidence in national government  Democratic Quality  Delivery Quality  \
# 0                           0.612072           -1.929690         -1.655084
# 1                           0.611545           -2.044093         -1.635025
# 2                           0.299357           -1.991810         -1.617176
# 3                           0.307386           -1.919018         -1.616221
# 4                           0.435440           -1.842996         -1.404078
#
#    Standard deviation of ladder by country-year  \
# 0                                      1.774662
# 1                                      1.722688
# 2                                      1.878622
# 3                                      1.785360
# 4                                      1.798283
#
#    Standard deviation/Mean of ladder by country-year
# 0                                           0.476600
# 1                                           0.391362
# 2                                           0.394803
# 3                                           0.465942
# 4                                           0.475367

# %%
df.info ()

#Let's collect our  parameters again.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 16 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country name                                       1704 non-null   object
#  1   Year                                               1704 non-null   int64
#  2   Life Ladder                                        1704 non-null   float64
#  3   Log GDP per capita                                 1676 non-null   float64
#  4   Social support                                     1691 non-null   float64
#  5   Healthy life expectancy at birth                   1676 non-null   float64
#  6   Freedom to make life choices                       1675 non-null   float64
#  7   Generosity                                         1622 non-null   float64
#  8   Perceptions of corruption                          1608 non-null   float64
#  9   Positive affect                                    1685 non-null   float64
#  10  Negative affect                                    1691 non-null   float64
#  11  Confidence in national government                  1530 non-null   float64
#  12  Democratic Quality                                 1558 non-null   float64
#  13  Delivery Quality                                   1559 non-null   float64
#  14  Standard deviation of ladder by country-year       1704 non-null   float64
#  15  Standard deviation/Mean of ladder by country-year  1704 non-null   float64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 213.1+ KB

# %%
dups = df

print (dups.any ())

#I know we don't have duplicates, but I just want to make sure.
# Out:
# Country name                                         True
# Year                                                 True
# Life Ladder                                          True
# Log GDP per capita                                   True
# Social support                                       True
# Healthy life expectancy at birth                     True
# Freedom to make life choices                         True
# Generosity                                           True
# Perceptions of corruption                            True
# Positive affect                                      True
# Negative affect                                      True
# Confidence in national government                    True
# Democratic Quality                                   True
# Delivery Quality                                     True
# Standard deviation of ladder by country-year         True
# Standard deviation/Mean of ladder by country-year    True
# dtype: bool

# %%
df= pd.read_csv('Malaria_report.csv')

print(df.shape)
print(df.info())

# Finally, I try to find and identify the presence of Outliers in my dataset.
# Out:
# (1704, 26)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 26 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   Country name                                              1704 non-null   object
#  1   Year                                                      1704 non-null   int64
#  2   Life Ladder                                               1704 non-null   float64
#  3   Log GDP per capita                                        1676 non-null   float64
#  4   Social support                                            1691 non-null   float64
#  5   Healthy life expectancy at birth                          1676 non-null   float64
#  6   Freedom to make life choices                              1675 non-null   float64
#  7   Generosity                                                1622 non-null   float64
#  8   Perceptions of corruption                                 1608 non-null   float64
#  9   Positive affect                                           1685 non-null   float64
#  10  Negative affect                                           1691 non-null   float64
#  11  Confidence in national government                         1530 non-null   float64
#  12  Democratic Quality                                        1558 non-null   float64
#  13  Delivery Quality                                          1559 non-null   float64
#  14  Standard deviation of ladder by country-year              1704 non-null   float64
#  15  Standard deviation/Mean of ladder by country-year         1704 non-null   float64
#  16  GINI index (World Bank estimate)                          643 non-null    float64
#  17  GINI index (World Bank estimate), average 2000-16         1502 non-null   float64
#  18  gini of household income reported in Gallup, by wp5-year  1335 non-null   float64
#  19  Most people can be trusted, Gallup                        180 non-null    float64
#  20  Most people can be trusted, WVS round 1981-1984           125 non-null    float64
#  21  Most people can be trusted, WVS round 1989-1993           220 non-null    float64
#  22  Most people can be trusted, WVS round 1994-1998           618 non-null    float64
#  23  Most people can be trusted, WVS round 1999-2004           491 non-null    float64
#  24  Most people can be trusted, WVS round 2005-2009           630 non-null    float64
#  25  Most people can be trusted, WVS round 2010-2014           671 non-null    float64
# dtypes: float64(24), int64(1), object(1)
# memory usage: 346.2+ KB
# None

# %%
df.describe ()

# I first look at my data again, to physically check for outliers.
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# count  1704.000000  1704.000000         1676.000000     1691.000000
# mean   2012.332160     5.437155            9.222456        0.810570
# std       3.688072     1.121149            1.185794        0.119210
# min    2005.000000     2.661718            6.457201        0.290184
# 25%    2009.000000     4.610970            8.304428        0.747512
# 50%    2012.000000     5.339557            9.406206        0.833098
# 75%    2015.000000     6.273522           10.193060        0.904432
# max    2018.000000     8.018934           11.770276        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1676.000000                   1675.000000
# mean                          63.111971                      0.733829
# std                            7.583622                      0.144115
# min                           32.299999                      0.257534
# 25%                           58.299999                      0.638436
# 50%                           65.000000                      0.752731
# 75%                           68.300003                      0.848155
# max                           76.800003                      0.985178
#
#         Generosity  Perceptions of corruption  Positive affect  \
# count  1622.000000                1608.000000      1685.000000
# mean      0.000079                   0.751315         0.709368
# std       0.163365                   0.186074         0.107984
# min      -0.336385                   0.035198         0.362498
# 25%      -0.115534                   0.696083         0.621855
# 50%      -0.022080                   0.805775         0.718541
# 75%       0.093522                   0.876458         0.801530
# max       0.677743                   0.983276         0.943621
#
#        Negative affect  ...  GINI index (World Bank estimate)  \
# count      1691.000000  ...                        643.000000
# mean          0.265679  ...                          0.370000
# std           0.084707  ...                          0.083232
# min           0.083426  ...                          0.240000
# 25%           0.205414  ...                          0.305000
# 50%           0.254544  ...                          0.352000
# 75%           0.314896  ...                          0.428000
# max           0.704590  ...                          0.634000
#
#        GINI index (World Bank estimate), average 2000-16  \
# count                                        1502.000000
# mean                                            0.385438
# std                                             0.082396
# min                                             0.211000
# 25%                                             0.321429
# 50%                                             0.371000
# 75%                                             0.432200
# max                                             0.626000
#
#        gini of household income reported in Gallup, by wp5-year  \
# count                                        1335.000000
# mean                                            0.447771
# std                                             0.108505
# min                                             0.200969
# 25%                                             0.368424
# 50%                                             0.426541
# 75%                                             0.514803
# max                                             0.961435
#
#        Most people can be trusted, Gallup  \
# count                          180.000000
# mean                             0.226295
# std                              0.119079
# min                              0.066618
# 25%                              0.139773
# 50%                              0.198450
# 75%                              0.281627
# max                              0.640332
#
#        Most people can be trusted, WVS round 1981-1984  \
# count                                       125.000000
# mean                                          0.390480
# std                                           0.123309
# min                                           0.176535
# 25%                                           0.290300
# 50%                                           0.380174
# 75%                                           0.478149
# max                                           0.571719
#
#        Most people can be trusted, WVS round 1989-1993  \
# count                                       220.000000
# mean                                          0.283925
# std                                           0.113226
# min                                           0.066020
# 25%                                           0.223553
# 50%                                           0.292383
# 75%                                           0.341741
# max                                           0.594595
#
#        Most people can be trusted, WVS round 1994-1998  \
# count                                       618.000000
# mean                                          0.249574
# std                                           0.118126
# min                                           0.048720
# 25%                                           0.176876
# 50%                                           0.229924
# 75%                                           0.294242
# max                                           0.647737
#
#        Most people can be trusted, WVS round 1999-2004  \
# count                                       491.000000
# mean                                          0.268070
# std                                           0.145120
# min                                           0.075872
# 25%                                           0.155833
# 50%                                           0.232000
# 75%                                           0.385469
# max                                           0.637185
#
#        Most people can be trusted, WVS round 2005-2009  \
# count                                       630.000000
# mean                                          0.264336
# std                                           0.160169
# min                                           0.038242
# 25%                                           0.144976
# 50%                                           0.198380
# 75%                                           0.391370
# max                                           0.737305
#
#        Most people can be trusted, WVS round 2010-2014
# count                                       671.000000
# mean                                          0.237493
# std                                           0.157482
# min                                           0.031518
# 25%                                           0.118725
# 50%                                           0.193531
# 75%                                           0.335000
# max                                           0.661757
#
# [8 rows x 25 columns]

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)

# Here, I chose to identify outliers with Interquartile Range (IQR).
# Out:
# Year                                                         6.000000
# Life Ladder                                                  1.662552
# Log GDP per capita                                           1.888633
# Social support                                               0.156920
# Healthy life expectancy at birth                            10.000004
# Freedom to make life choices                                 0.209719
# Generosity                                                   0.209056
# Perceptions of corruption                                    0.180375
# Positive affect                                              0.179675
# Negative affect                                              0.109483
# Confidence in national government                            0.280127
# Democratic Quality                                           1.440930
# Delivery Quality                                             1.411387
# Standard deviation of ladder by country-year                 0.498930
# Standard deviation/Mean of ladder by country-year            0.146172
# GINI index (World Bank estimate)                             0.123000
# GINI index (World Bank estimate), average 2000-16            0.110771
# gini of household income reported in Gallup, by wp5-year     0.146379
# Most people can be trusted, Gallup                           0.141854
# Most people can be trusted, WVS round 1981-1984              0.187849
# Most people can be trusted, WVS round 1989-1993              0.118188
# Most people can be trusted, WVS round 1994-1998              0.117366
# Most people can be trusted, WVS round 1999-2004              0.229636
# Most people can be trusted, WVS round 2005-2009              0.246393
# Most people can be trusted, WVS round 2010-2014              0.216275
# dtype: float64

# %%
print(df < (Q1 - 1.5 * IQR))
(df > (Q3 + 1.5 * IQR))

# I scan my data were the values show "True" 
# because that depicts presence of Outliers.
# I found no outliers present in my data.
# I now move to analysis portion of my work.
# Out:
#       Confidence in national government  Country name  Delivery Quality  \
# 0                                 False         False             False
# 1                                 False         False             False
# 2                                 False         False             False
# 3                                 False         False             False
# 4                                 False         False             False
# ...                                 ...           ...               ...
# 1699                              False         False             False
# 1700                              False         False             False
# 1701                              False         False             False
# 1702                              False         False             False
# 1703                              False         False             False
#
#       Democratic Quality  Freedom to make life choices  \
# 0                  False                         False
# 1                  False                         False
# 2                  False                         False
# 3                  False                         False
# 4                  False                         False
# ...                  ...                           ...
# 1699               False                         False
# 1700               False                         False
# 1701               False                         False
# 1702               False                         False
# 1703               False                         False
#
#       GINI index (World Bank estimate)  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 1699                             False
# 1700                             False
# 1701                             False
# 1702                             False
# 1703                             False
#
#       GINI index (World Bank estimate), average 2000-16  Generosity  \
# 0                                                 False       False
# 1                                                 False       False
# 2                                                 False       False
# 3                                                 False       False
# 4                                                 False       False
# ...                                                 ...         ...
# 1699                                              False       False
# 1700                                              False       False
# 1701                                              False       False
# 1702                                              False       False
# 1703                                              False       False
#
#       Healthy life expectancy at birth  Life Ladder  ...  \
# 0                                False        False  ...
# 1                                False        False  ...
# 2                                False        False  ...
# 3                                False        False  ...
# 4                                False        False  ...
# ...                                ...          ...  ...
# 1699                             False        False  ...
# 1700                             False        False  ...
# 1701                             False        False  ...
# 1702                             False        False  ...
# 1703                             False        False  ...
#
#       Most people can be trusted, WVS round 2005-2009  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 1699                                            False
# 1700                                            False
# 1701                                            False
# 1702                                            False
# 1703                                            False
#
#       Most people can be trusted, WVS round 2010-2014  Negative affect  \
# 0                                               False            False
# 1                                               False            False
# 2                                               False            False
# 3                                               False            False
# 4                                               False            False
# ...                                               ...              ...
# 1699                                            False            False
# 1700                                            False            False
# 1701                                            False            False
# 1702                                            False            False
# 1703                                            False            False
#
#       Perceptions of corruption  Positive affect  Social support  \
# 0                         False            False            True
# 1                         False            False           False
# 2                         False            False           False
# 3                         False            False           False
# 4                         False            False           False
# ...                         ...              ...             ...
# 1699                      False            False           False
# 1700                      False            False           False
# 1701                      False            False           False
# 1702                      False            False           False
# 1703                      False            False           False
#
#       Standard deviation of ladder by country-year  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 1699                                         False
# 1700                                         False
# 1701                                         False
# 1702                                         False
# 1703                                         False
#
#       Standard deviation/Mean of ladder by country-year   Year  \
# 0                                                 False  False
# 1                                                 False  False
# 2                                                 False  False
# 3                                                 False  False
# 4                                                 False  False
# ...                                                 ...    ...
# 1699                                              False  False
# 1700                                              False  False
# 1701                                              False  False
# 1702                                              False  False
# 1703                                              False  False
#
#       gini of household income reported in Gallup, by wp5-year
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1699                                              False
# 1700                                              False
# 1701                                              False
# 1702                                              False
# 1703                                              False
#
# [1704 rows x 26 columns]
#       Confidence in national government  Country name  Delivery Quality  \
# 0                                 False         False             False
# 1                                 False         False             False
# 2                                 False         False             False
# 3                                 False         False             False
# 4                                 False         False             False
# ...                                 ...           ...               ...
# 1699                              False         False             False
# 1700                              False         False             False
# 1701                              False         False             False
# 1702                              False         False             False
# 1703                              False         False             False
#
#       Democratic Quality  Freedom to make life choices  \
# 0                  False                         False
# 1                  False                         False
# 2                  False                         False
# 3                  False                         False
# 4                  False                         False
# ...                  ...                           ...
# 1699               False                         False
# 1700               False                         False
# 1701               False                         False
# 1702               False                         False
# 1703               False                         False
#
#       GINI index (World Bank estimate)  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 1699                             False
# 1700                             False
# 1701                             False
# 1702                             False
# 1703                             False
#
#       GINI index (World Bank estimate), average 2000-16  Generosity  \
# 0                                                 False       False
# 1                                                 False       False
# 2                                                 False       False
# 3                                                 False       False
# 4                                                 False       False
# ...                                                 ...         ...
# 1699                                              False       False
# 1700                                              False       False
# 1701                                              False       False
# 1702                                              False       False
# 1703                                              False       False
#
#       Healthy life expectancy at birth  Life Ladder  ...  \
# 0                                False        False  ...
# 1                                False        False  ...
# 2                                False        False  ...
# 3                                False        False  ...
# 4                                False        False  ...
# ...                                ...          ...  ...
# 1699                             False        False  ...
# 1700                             False        False  ...
# 1701                             False        False  ...
# 1702                             False        False  ...
# 1703                             False        False  ...
#
#       Most people can be trusted, WVS round 2005-2009  \
# 0                                               False
# 1                                               False
# 2                                               False
# 3                                               False
# 4                                               False
# ...                                               ...
# 1699                                            False
# 1700                                            False
# 1701                                            False
# 1702                                            False
# 1703                                            False
#
#       Most people can be trusted, WVS round 2010-2014  Negative affect  \
# 0                                               False            False
# 1                                               False            False
# 2                                               False            False
# 3                                               False            False
# 4                                               False            False
# ...                                               ...              ...
# 1699                                            False            False
# 1700                                            False            False
# 1701                                            False            False
# 1702                                            False            False
# 1703                                            False            False
#
#       Perceptions of corruption  Positive affect  Social support  \
# 0                         False            False           False
# 1                         False            False           False
# 2                         False            False           False
# 3                         False            False           False
# 4                         False            False           False
# ...                         ...              ...             ...
# 1699                      False            False           False
# 1700                      False            False           False
# 1701                      False            False           False
# 1702                      False            False           False
# 1703                      False            False           False
#
#       Standard deviation of ladder by country-year  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 1699                                         False
# 1700                                         False
# 1701                                         False
# 1702                                         False
# 1703                                         False
#
#       Standard deviation/Mean of ladder by country-year   Year  \
# 0                                                 False  False
# 1                                                 False  False
# 2                                                 False  False
# 3                                                 False  False
# 4                                                 False  False
# ...                                                 ...    ...
# 1699                                              False  False
# 1700                                              False  False
# 1701                                               True  False
# 1702                                               True  False
# 1703                                               True  False
#
#       gini of household income reported in Gallup, by wp5-year
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 1699                                              False
# 1700                                              False
# 1701                                              False
# 1702                                              False
# 1703                                              False
#
# [1704 rows x 26 columns]

# %%
## Now the data is ready for analysis.
## The primary goal of this project is to show why we should end one of the deadliest 
## diseases in human history, MALARIA, and to show how that is possible in this lifetime.

#Hypothesis 1: Ending Malaria Stimulates Economy.
#Hypothesis 2: Ending Malaria helps keep us safer and healthier.
#Hypothesis 3: Ending Malaria saves lives and stops the cycle of poverty.

# %%
## This graph depicts how ending Malaria stimulates Economy.
## I showed the correlation between Life Ladder and Log GDP per capita 
df.plot (x='Life Ladder', y='Log GDP per capita', kind='scatter')

# %%
## This illustration proves that ending Malaria helps keep us safer and healthier.
malaria_data= {'Healthy life expectancy at birth':np.random.rand(20),'Perceptions of corruption':np.random.rand(20)}
df=pd.DataFrame (malaria_data)
df.plot ( x='Healthy life expectancy at birth', y='Perceptions of corruption', kind='bar', color='green')

# %%
## This next illustration proves that ending Malaria saves lives and stops the cycle of poverty.
df= pd.read_csv('Malaria_report.csv')

df.plot (x='Healthy life expectancy at birth', y='Positive affect', kind='bar', color='pink')
plt.show()

# %%
This concludes my research.

References: 
https://www.malarianomore.org/about-us/
https://www.kaggle.com/search?q=malaria+in%3Adatasets
